# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm=ChatGoogleGenerativeAI(model="gemini-3.6-flash")

# %%
####Managing History

# %%
history=[]
while True:
    query=input("User:")
    if query.lower() in ["quit","exit"]:
        print("Good bye")
        break
    history.append({"role":"user","content":query})
    print("User: ",query)

    res=llm.invoke(history)
    history.append({"role":"ai","content":res.text})
    print("AI:",res.text,"\n")
# Out:
# User:  bye
# AI: Goodbye! Have a great day, and feel free to reach out if you need anything else later!
#
# User:  exxit
# AI: Goodbye! Take care, and see you next time!
#
# Good bye
