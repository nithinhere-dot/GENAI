# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm=ChatGoogleGenerativeAI(model="gemini-3.6-flash",streaming=True)

# %%
prompt="What is Gen ai"

# %%
res=llm.invoke(prompt)
for chunk in res.text:
    print(chunk,end="")
# Out:
# **Generative AI (GenAI)** is a type of artificial intelligence that can create **new, original content**—such as text, images, videos, audio, software code, and 3D models—in response to simple user prompts.
#
# Unlike traditional AI, which is designed to analyze data and make predictions, Generative AI learns patterns from massive amounts of existing data and uses that knowledge to **generate something entirely new** that resembles human creation.
#
# ---
#
# ### How Does Generative AI Work?
#
# 1. **Training (Learning):** GenAI models are fed vast datasets (e.g., billions of books, articles, code repositories, or images). The AI analyzes this data to understand grammar, context, artistic styles, relationships between words, and visual structures.
# 2. **Prompting (Input):** A human gives the AI an instruction, known as a **prompt** (e.g., *"Write a poem about a robot falling in love"* or *"Generate an image of a astronaut riding a horse on Mars"*).
# 3. **Generation (Output):** Using statistical probability, the model predicts what words, pixels, or notes should come next to produce a coherent response that matches the user's request.
#
# ---
#
# ### Types of Generative AI (With Popular Examples)
#
# * **Text Generation (Large Language Models / LLMs):**
#   * *What it does:* Writes essays, drafts emails, summarizes long documents, translates languages, and holds natural conversations.
#   * *Examples:* ChatGPT (OpenAI), Claude (Anthropic), Gemini (Google).
# * **Image Generation:**
#   * *What it does:* Creates realistic photos, digital art, or graphic designs from text descriptions.
#   * *Examples:* Midjourney, DALL-E 3, Stable Diffusion.
# * **Code Generation:**
#   * *What it does:* Writes, debugs, and explains programming code in Python, JavaScript, C++, and more.
#   * *Examples:* GitHub Copilot, Cursor, Replit.
# * **Video Generation:**
#   * *What it does:* Creates short video clips or animations from text or static images.
#   * *Examples:* OpenAI Sora, Runway Gen-2, Pika.
# * **Audio and Music Generation:**
#   * *What it does:* Clones voices, creates realistic text-to-speech, or composes full songs with lyrics and vocals.
#   * *Examples:* ElevenLabs, Suno, Udio.
#
# ---
#
# ### Traditional AI vs. Generative AI
#
# To understand the difference, imagine a photo of a dog:
# * **Traditional AI** looks at the photo and answers: *"Is this a dog or a cat?"* (Classification/Analysis)
# * **Generative AI** receives the instruction *"Draw a golden retriever wearing a tuxedo"* and **creates an image that never existed before.**
#
# ---
#
# ### Why is GenAI So Big Right Now?
#
# * **Accessibility:** Anyone can use it using natural human language (English, Spanish, etc.)—no coding skills required.
# * **Productivity:** It drastically reduces the time needed to draft documents, write software, design graphics, or conduct research.
# * **Democratization of Creativity:** It allows non-artists to make art, non-programmers to make software, and small businesses to create professional marketing materials.
#
# ---
#
# ### Key Challenges and Risks
#
# While powerful, Generative AI comes with major concerns:
# 1. **Hallucinations:** GenAI can confidently present false information as absolute fact.
# 2. **Copyright & Intellectual Property:** Models are often trained on copyrighted works without the original creators' permission or compensation.
# 3. **Deepfakes & Misinformation:** The technology makes it easy to generate convincing fake news, fake images, or voice-cloned scams.
# 4. **Bias:** If the training data contains societal biases, the AI will reproduce those biases in its output.
# 5. **Job Displacement:** It is changing the nature of work for writers, artists, coders, customer support agents, and knowledge workers.
