# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm= ChatGoogleGenerativeAI(model="gemini-3.6-flash")

# %%
####Discuss the Problem First

# %%
text="Hello My name Is nithin Kumar"\
"Email is nithinhere@gmail.com and my age is 21"

# %%
res=llm.invoke(f"Please give me only name,email and age from this text {text}")
res
# Out:
# AIMessage(content=[{'type': 'text', 'text': '**Name:** nithin Kumar  \n**Email:** nithinhere@gmail.com  \n**Age:** 21', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.6-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a0b907-0664-7942-a541-e3bc5b9439fc-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 36, 'output_tokens': 407, 'total_tokens': 443, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 381}})

# %%
###solution is Structured Output

# %%
from pydantic import BaseModel,Field
class ResponseStructure(BaseModel):
    name:str=Field(description="Complete Name")
    email:str=Field(description="Email addres ")
    age:int=Field(description="Age")
structured_llm=llm.with_structured_output(ResponseStructure)

# %%
res=structured_llm.invoke(f"Please give me only name,email and age from this text {text}")
print(res.name)
# Out:
# nithin Kumar
